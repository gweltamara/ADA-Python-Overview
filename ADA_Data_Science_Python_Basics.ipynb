# %% [markdown]
# <a href="https://colab.research.google.com/github/gweltamara/ADA-Python-Overview/blob/main/ADA_Data_Science_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Checking files in directory

# %%
# List files in the current directory (Windows)
# !dir
# Out:
# sample_data  SuperStore-Data.csv  SuperStore-Data.xlsx

# %% [markdown]
# Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing Data and Reading CSV File

# %%
## This works as long as our file is in the directory

# Importing data
Data = 'SuperStore-Data.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(Data)

# Display the first few rows of the DataFrame
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation              D  84835.0        0         0
# 1      1        1961  Graduation              S  57091.0        0         0
# 2  10476        1958  Graduation              M  67267.0        0         1
# 3   1386        1967  Graduation              T  32474.0        1         1
# 4   5371        1989  Graduation              S  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# Defining variables and their data types
number = 42  # Integer
text = "Hello, World!"  # String
is_true = True  # Boolean
floating_point = 3.14  # Float
